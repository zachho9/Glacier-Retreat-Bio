# %%
# from pygbif import species as species
# from pygbif import occurrences as occ

import pandas as pd
import numpy as np
import geopandas as gpd
# Out:
# INFO:NumExpr defaulting to 8 threads.

# %%
df_sw = pd.read_csv("data/gbif_nz_snow_wren.csv", sep='\t')
df_sw.head()
# Out:
#       gbifID                            datasetKey  \
# 0  977205778  4fa7b334-ce0d-4e88-aaae-2e0c138d049e
# 1  976924999  4fa7b334-ce0d-4e88-aaae-2e0c138d049e
# 2  964538944  4fa7b334-ce0d-4e88-aaae-2e0c138d049e
# 3  964226612  4fa7b334-ce0d-4e88-aaae-2e0c138d049e
# 4  962468066  4fa7b334-ce0d-4e88-aaae-2e0c138d049e
#
#                             occurrenceID   kingdom    phylum class  \
# 0     URN:catalog:CLO:EBIRD:OBS225716267  Animalia  Chordata  Aves
# 1  URN:catalog:CLO:EBIRD_NZ:OBS224521212  Animalia  Chordata  Aves
# 2     URN:catalog:CLO:EBIRD:OBS209872557  Animalia  Chordata  Aves
# 3  URN:catalog:CLO:EBIRD_NZ:OBS209588518  Animalia  Chordata  Aves
# 4     URN:catalog:CLO:EBIRD:OBS207823760  Animalia  Chordata  Aves
#
#            order           family    genus               species  ...  \
# 0  Passeriformes  Acanthisittidae  Xenicus  Xenicus gilviventris  ...
# 1  Passeriformes  Acanthisittidae  Xenicus  Xenicus gilviventris  ...
# 2  Passeriformes  Acanthisittidae  Xenicus  Xenicus gilviventris  ...
# 3  Passeriformes  Acanthisittidae  Xenicus  Xenicus gilviventris  ...
# 4  Passeriformes  Acanthisittidae  Xenicus  Xenicus gilviventris  ...
#
#    identifiedBy dateIdentified    license rightsHolder  recordedBy typeStatus  \
# 0           NaN            NaN  CC_BY_4_0          NaN  obsr337627        NaN
# 1           NaN            NaN  CC_BY_4_0          NaN  obsr444699        NaN
# 2           NaN            NaN  CC_BY_4_0          NaN  obsr284567        NaN
# 3           NaN            NaN  CC_BY_4_0          NaN  obsr329542        NaN
# 4           NaN            NaN  CC_BY_4_0          NaN  obsr292802        NaN
#
#   establishmentMeans           lastInterpreted mediaType  \
# 0                NaN  2024-04-17T08:23:32.337Z       NaN
# 1                NaN  2024-04-17T09:07:24.802Z       NaN
# 2                NaN  2024-04-17T09:06:42.352Z       NaN
# 3                NaN  2024-04-17T09:11:09.307Z       NaN
# 4                NaN  2024-04-17T08:45:03.835Z       NaN
#
#                                                issue
# 0  CONTINENT_DERIVED_FROM_COORDINATES;TAXON_MATCH...
# 1  CONTINENT_DERIVED_FROM_COORDINATES;TAXON_MATCH...
# 2  CONTINENT_DERIVED_FROM_COORDINATES;TAXON_MATCH...
# 3  CONTINENT_DERIVED_FROM_COORDINATES;TAXON_MATCH...
# 4  CONTINENT_DERIVED_FROM_COORDINATES;TAXON_MATCH...
#
# [5 rows x 50 columns]

# %%
df_sw.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2477 entries, 0 to 2476
# Data columns (total 50 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   gbifID                            2477 non-null   int64
#  1   datasetKey                        2477 non-null   object
#  2   occurrenceID                      2458 non-null   object
#  3   kingdom                           2477 non-null   object
#  4   phylum                            2477 non-null   object
#  5   class                             2477 non-null   object
#  6   order                             2477 non-null   object
#  7   family                            2477 non-null   object
#  8   genus                             2477 non-null   object
#  9   species                           2477 non-null   object
#  10  infraspecificEpithet              0 non-null      float64
#  11  taxonRank                         2477 non-null   object
#  12  scientificName                    2477 non-null   object
#  13  verbatimScientificName            2477 non-null   object
#  14  verbatimScientificNameAuthorship  5 non-null      object
#  15  countryCode                       2477 non-null   object
#  16  locality                          2214 non-null   object
#  17  stateProvince                     2445 non-null   object
#  18  occurrenceStatus                  2477 non-null   object
#  19  individualCount                   1186 non-null   float64
#  20  publishingOrgKey                  2477 non-null   object
#  21  decimalLatitude                   2456 non-null   float64
#  22  decimalLongitude                  2456 non-null   float64
#  23  coordinateUncertaintyInMeters     255 non-null    float64
#  24  coordinatePrecision               0 non-null      float64
#  25  elevation                         0 non-null      float64
#  26  elevationAccuracy                 0 non-null      float64
#  27  depth                             0 non-null      float64
#  28  depthAccuracy                     0 non-null      float64
#  29  eventDate                         2474 non-null   object
#  30  day                               2457 non-null   float64
#  31  month                             2473 non-null   float64
#  32  year                              2474 non-null   float64
#  33  taxonKey                          2477 non-null   int64
#  34  speciesKey                        2477 non-null   int64
#  35  basisOfRecord                     2477 non-null   object
#  36  institutionCode                   2452 non-null   object
#  37  collectionCode                    2458 non-null   object
#  38  catalogNumber                     2458 non-null   object
#  39  recordNumber                      0 non-null      float64
#  40  identifiedBy                      259 non-null    object
#  41  dateIdentified                    257 non-null    object
#  42  license                           2477 non-null   object
#  43  rightsHolder                      283 non-null    object
#  44  recordedBy                        2473 non-null   object
#  45  typeStatus                        0 non-null      float64
#  46  establishmentMeans                19 non-null     object
#  47  lastInterpreted                   2477 non-null   object
#  48  mediaType                         255 non-null    object
#  49  issue                             2461 non-null   object
# dtypes: float64(15), int64(3), object(32)
# memory usage: 967.7+ KB

# %%
df_sw_time_1 = df_sw[df_sw['year'] == 2012.0]

gpd_df_sw_time_1 = (
    gpd.GeoDataFrame(
        df_sw_time_1, geometry=gpd.points_from_xy(df_sw_time_1.decimalLongitude, df_sw_time_1.decimalLatitude), crs="EPSG:4326"
    )
)

gpd_df_sw_time_1.explore()
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_f371f1f1affebb0d8f57cc45318ccf4a {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_f371f1f1affebb0d8f57cc45318ccf4a&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_f371f1f1affebb0d8f57cc45318ccf4a = L.map(
#                 &quot;map_f371f1f1affebb0d8f57cc45318ccf4a&quot;,
#                 {
#                     center: [-43.7833655, 170.04084],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_f371f1f1affebb0d8f57cc45318ccf4a);
#
#
#
#
#
#             var tile_layer_8332d19cd2d88ceee1f717f5f4d9a5a2 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_f371f1f1affebb0d8f57cc45318ccf4a);
#
#
#             map_f371f1f1affebb0d8f57cc45318ccf4a.fitBounds(
#                 [[-45.053635, 167.97299], [-42.513096, 172.10869]],
#                 {}
#             );
#
#
#         function geo_json_d164eec7412d44b50f09822deb401979_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#             }
#         }
#         function geo_json_d164eec7412d44b50f09822deb401979_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.75};
#             }
#         }
#         function geo_json_d164eec7412d44b50f09822deb401979_pointToLayer(feature, latlng) {
#             var opts = {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 3};
#
#             let style = geo_json_d164eec7412d44b50f09822deb401979_styler(feature)
#             Object.assign(opts, style)
#
#             return new L.CircleMarker(latlng, opts)
#         }
#
#         function geo_json_d164eec7412d44b50f09822deb401979_onEachFeature(feature, layer) {
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         geo_json_d164eec7412d44b50f09822deb401979.resetStyle(e.target);
#                     }
#                 },
#                 mouseover: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         const highlightStyle = geo_json_d164eec7412d44b50f09822deb401979_highlighter(e.target.feature)
#                         e.target.setStyle(highlightStyle);
#                     }
#                 },
#             });
#         };
#         var geo_json_d164eec7412d44b50f09822deb401979 = L.geoJson(null, {
#                 onEachFeature: geo_json_d164eec7412d44b50f09822deb401979_onEachFeature,
#
#                 style: geo_json_d164eec7412d44b50f09822deb401979_styler,
#                 pointToLayer: geo_json_d164eec7412d44b50f09822deb401979_pointToLayer
#         });
#
#         function geo_json_d164eec7412d44b50f09822deb401979_add (data) {
#             geo_json_d164eec7412d44b50f09822deb401979
#                 .addData(data)
#                 .addTo(map_f371f1f1affebb0d8f57cc45318ccf4a);
#         }
#             geo_json_d164eec7412d44b50f09822deb401979_add({&quot;bbox&quot;: [167.97299, -45.053635, 172.10869, -42.513096], &quot;features&quot;: [{&quot;bbox&quot;: [168.52977, -44.504765, 168.52977, -44.504765], &quot;geometry&quot;: {&quot;coordinates&quot;: [168.52977, -44.504765], &quot;type&quot;: &quot;Point&quot;}, &quot;id&quot;: &quot;51&quot;, &quot;properties&quot;: {&quot;basisOfRecord&quot;: &quot;HUMAN_OBSERVATION&quot;, &quot;catalogNumber&quot;: &quot;OBS183436603&quot;, &quot;class&quot;: &quot;Aves&quot;, &quot;collectionCode&quot;: &quot;EBIRD&quot;, &quot;coordinatePrecision&quot;: null, &quot;coordinateUncertaintyInMeters&quot;: null, &quot;countryCode&quot;: &quot;NZ&quot;, &quot;datasetKey&quot;: &quot;4fa7b334

# %%
df_sw_time_2 = df_sw[df_sw['year'] == 2022.0]

gpd_df_sw_time_2 = (
    gpd.GeoDataFrame(
        df_sw_time_2, geometry=gpd.points_from_xy(df_sw_time_2.decimalLongitude, df_sw_time_2.decimalLatitude), crs="EPSG:4326"
    )
)

gpd_df_sw_time_2.explore()
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_aa7345d15f1bc03aa52f4707568a404b {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_aa7345d15f1bc03aa52f4707568a404b&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_aa7345d15f1bc03aa52f4707568a404b = L.map(
#                 &quot;map_aa7345d15f1bc03aa52f4707568a404b&quot;,
#                 {
#                     center: [-44.1891385, 169.73799200000002],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_aa7345d15f1bc03aa52f4707568a404b);
#
#
#
#
#
#             var tile_layer_7ede8adaceaa2379b81594c06348b03b = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_aa7345d15f1bc03aa52f4707568a404b);
#
#
#             map_aa7345d15f1bc03aa52f4707568a404b.fitBounds(
#                 [[-45.979317, 167.03566], [-42.39896, 172.440324]],
#                 {}
#             );
#
#
#         function geo_json_bb8b73a858ab474b8782f8bf6efc8e0d_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#             }
#         }
#         function geo_json_bb8b73a858ab474b8782f8bf6efc8e0d_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.75};
#             }
#         }
#         function geo_json_bb8b73a858ab474b8782f8bf6efc8e0d_pointToLayer(feature, latlng) {
#             var opts = {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 3};
#
#             let style = geo_json_bb8b73a858ab474b8782f8bf6efc8e0d_styler(feature)
#             Object.assign(opts, style)
#
#             return new L.CircleMarker(latlng, opts)
#         }
#
#         function geo_json_bb8b73a858ab474b8782f8bf6efc8e0d_onEachFeature(feature, layer) {
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         geo_json_bb8b73a858ab474b8782f8bf6efc8e0d.resetStyle(e.target);
#                     }
#                 },
#                 mouseover: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         const highlightStyle = geo_json_bb8b73a858ab474b8782f8bf6efc8e0d_highlighter(e.target.feature)
#                         e.target.setStyle(highlightStyle);
#                     }
#                 },
#             });
#         };
#         var geo_json_bb8b73a858ab474b8782f8bf6efc8e0d = L.geoJson(null, {
#                 onEachFeature: geo_json_bb8b73a858ab474b8782f8bf6efc8e0d_onEachFeature,
#
#                 style: geo_json_bb8b73a858ab474b8782f8bf6efc8e0d_styler,
#                 pointToLayer: geo_json_bb8b73a858ab474b8782f8bf6efc8e0d_pointToLayer
#         });
#
#         function geo_json_bb8b73a858ab474b8782f8bf6efc8e0d_add (data) {
#             geo_json_bb8b73a858ab474b8782f8bf6efc8e0d
#                 .addData(data)
#                 .addTo(map_aa7345d15f1bc03aa52f4707568a404b);
#         }
#             geo_json_bb8b73a858ab474b8782f8bf6efc8e0d_add({&quot;bbox&quot;: [167.03566, -45.979317, 172.440324, -42.39896], &quot;features&quot;: [{&quot;bbox&quot;: [168.41063, -45.884003, 168.41063, -45.884003], &quot;geometry&quot;: {&quot;coordinates&quot;: [168.41063, -45.884003], &quot;type&quot;: &quot;Point&quot;}, &quot;id&quot;: &quot;1211&quot;, &quot;properties&quot;: {&quot;basisOfRecord&quot;: &quot;HUMAN_OBSERVATION&quot;, &quot;catalogNumber&quot;: &quot;OBS1869126941&quot;, &quot;class&quot;: &quot;Aves&quot;, &quot;collectionCode&quot;: &quot;EBIRD&quot;, &quot;coordinatePrecision&quot;: null, &quot;coordinateUncertaintyInMeters&quot;: null, &quot;countryCode&quot;: &quot;NZ&quot;, &quot;datasetKey&quot;: &q
